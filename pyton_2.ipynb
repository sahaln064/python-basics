# %% [markdown]
# <a href="https://colab.research.google.com/github/sahaln064/python-basics/blob/main/pyton_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# Enter a number: 4
# even

# %%
age = 10
if age >=18:
  print("eligible to login")
else:
  print("not eligible to login")
# Out:
# not eligible to login

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
if a>b:
  print("a is the largest")
else:
    print("b is the largest")
# Out:
# enter first number3
# enter second number2
# a is the largest

# %%
username= input("enter username:")
password= (input("enter password:"))
username1=input("enter username to login:")
passwords=input("enter password")
if(password == passwords and username == username1):
  print("login successful welcome",username1)
else:
  print("login failed")
# Out:
# enter username:sahal
# enter password:123
# enter username to login:sahal
# enter password123
# login successful welcome sahal

# %%
a=[1,2,3,4]
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a=[1,2,3,4]
a.append(6)
print(a)
# Out:
# [1, 2, 3, 4, 6]

# %%
a=[1,2,3,4,5,6]
a.pop()
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a=[1,2,3,4,5,6]
a.remove(4)
print(a)
# Out:
# [1, 2, 3, 5, 6]

# %%
a=[1,2,3,4,5]
a.insert(5,7)
print(a)
# Out:
# [1, 2, 3, 4, 5, 7]

# %%
a=(1,2,3,4,5)
print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
a=(1,2,3,4)
b=list(a)
b.append(5)
a=tuple(b)
print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
a={1,2,3}
a.remove(3)
print(a)
# Out:
# {1, 2}

# %%
a=[1,2,3,4,5]
print(len(a))
# Out:
# 5

# %%
a=[1,2,3,4,5]
a.append(6)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[1,2,3,4,5]
print(a[-1])
# Out:
# 5

# %%
a=[1,2,3,4,5,6,7,8,9]
print(a[0])
# Out:
# 1

# %%
a={1,2,3,4,5,6,6}
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a={1,2,3,4,5,6}
a.add(7)
print(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a={1,2,3,4,5,6}
a.remove(3)
print(a)
# Out:
# {1, 2, 4, 5, 6}

# %%
a=(1,2,3,4,5,6)
print(a)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
a=(1,2,3,4,5)
print(a)
print("accesing element using index ", a[1])
print("lenght : ",len(a))
# Out:
# (1, 2, 3, 4, 5)
# accesing element using index  2
# lenght :  5

# %%
def sahal():
  print("helllo woerld")
sahal()
# Out:
# helllo woerld

# %%
def evenodd(a):
  if a % 2==0 :
    return 'even'
  else:
    return 'odd'
  print(a)
evenodd(5)
# Out:
# 'odd'

# %%
def square(n):
    return n*n
print(square(5))
# Out:
# 25

# %%
def max(a, b):
    if a > b:
        return a
    else:
        return b
    print(max(2,3))

# %%
import numpy as np
temp= np.array([30,32,31,29,35])
max_temp =np.max(temp)
min_temp = np.min(temp)
avg_temp = np.mean(temp)
print("temperatures:",temp)
print("max:",max_temp)
print("min:",min_temp)
print("average:",avg_temp)
# Out:
# temperatures: [30 32 31 29 35]
# max: 35
# min: 29
# average: 31.4

# %%
import numpy as np
mark = np.array([30,32,54,65,35])
updated_mark = mark + 5
passed = updated_mark >= 50
print("orginal marks:",temp)
print("updated mark:",updated_mark)
print("pass status:",passed)
# Out:
# orginal marks: [30 32 31 29 35]
# updated mark: [35 37 59 70 40]
# pass status: [False False  True  True False]

# %%
import numpy as np
vote = np.array([20,14,19,18,24])
updated_age = vote + 2
age = updated_age >=18
print("orginal age:",age)
print("updated age:",updated_age)
print("eligiblity:",eligibile)
# Out:
# orginal age: [ True False  True  True  True]
# updated age: [22 16 21 20 26]
# eligiblity: [ True False  True  True  True]

# %%
import pandas as pd
data = {'salaries':[5000,6000,5500,1200,4800]}
df = pd.DataFrame(data)
print(df.describe())
# Out:
#           salaries
# count     5.000000
# mean   4500.000000
# std    1902.629759
# min    1200.000000
# 25%    4800.000000
# 50%    5000.000000
# 75%    5500.000000
# max    6000.000000
